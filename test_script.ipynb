# %%
from data_reader import Data
from buckingham_pi_theorem.dimensional_analysis import DimensionalAnalysis

# %%
experiment = Data("C:/Users/truma/Downloads/test - random data.csv")
d = DimensionalAnalysis(experiment.parameters)
d.plot()
# Out:
# coefficients [ 1.37236275e+01  5.95380783e-03 -8.00964973e+02 -3.92641890e+00
#  -3.56762996e-04  7.59635205e+00 -3.63142187e-01  2.66632996e+04
#  -4.38372657e+03  2.35602875e+01]
